# %% [markdown]
# #13: Konversi nilai numerik ke dalam sejumlah kategori

# %% [markdown]
# Import Modules

# %%
import pandas as pd
import numpy as np

print(pd.__version__)
print(np.__version__)
# Out:
# 2.3.3
# 2.3.4

# %% [markdown]
# Persiapan Data Frame

# %%
n_rows = 10
n_cols = 1
cols = ('usia',)

df = pd.DataFrame(np.random.randint(1, 99, size=(n_rows, n_cols)), 
                  columns=cols)
df
# Out:
#    usia
# 0    61
# 1    91
# 2    92
# 3    49
# 4    74
# 5    72
# 6    92
# 7    41
# 8    58
# 9    45

# %% [markdown]
# Pengelompokkan nilai numerik ke dalam beberapa kategori menggunakan cut()

# %%
df['kelompok_usia'] = pd.cut(df['usia'], 
                             bins=[0, 18, 65, 99], 
                             labels=['anak', 'dewasa', 'manula'])
df
# Out:
#    usia kelompok_usia
# 0    61        dewasa
# 1    91        manula
# 2    92        manula
# 3    49        dewasa
# 4    74        manula
# 5    72        manula
# 6    92        manula
# 7    41        dewasa
# 8    58        dewasa
# 9    45        dewasa

# %% [markdown]
# #14: Menggabungkan (merge) dua Data Frame

# %% [markdown]
# Persiapan Data Frame

# %%
n_rows = 5
n_cols = 5
cols = tuple('ABCDE')

df = pd.DataFrame(np.random.randint(1, 20, size=(n_rows, n_cols)), 
                  columns=cols)
df
# Out:
#     A   B   C   D   E
# 0  18  10   9  18   6
# 1   4   9  11  18   5
# 2  13  17  16   9  15
# 3   6  17   9   3   9
# 4  17  14   2  15  16

# %%
df1 = df.copy(deep=True)
df1 = df1.drop([1, 4])
df1
# Out:
#     A   B   C   D   E
# 0  18  10   9  18   6
# 2  13  17  16   9  15
# 3   6  17   9   3   9

# %%
df2 = df.copy(deep=True)
df2 = df2.drop([0, 3])
df2
# Out:
#     A   B   C   D   E
# 1   4   9  11  18   5
# 2  13  17  16   9  15
# 4  17  14   2  15  16

# %% [markdown]
# Menggabungkan dua Data Frame

# %%
df_inner = pd.merge(df1, df2, how='inner')
df_inner
# Out:
#     A   B   C  D   E
# 0  13  17  16  9  15

# %%
df_outer = pd.merge(df1, df2, how='outer')
df_outer
# Out:
#     A   B   C   D   E
# 0   4   9  11  18   5
# 1   6  17   9   3   9
# 2  13  17  16   9  15
# 3  17  14   2  15  16
# 4  18  10   9  18   6

# %% [markdown]
# #15: Memecah nilai string dari suatu kolom ke dalam beberapa kolom baru

# %% [markdown]
# Persiapan Data Frame

# %%
data = {'nama':['Ahmad Dhani', 'Nadin Amizah', 'Reza Rahadian'], 
        'tempat_kelahiran':['Surakarta, Jawa Tengah', 'Jakarta, DKI Jakarta', 'Mojokerto, Jawa Timur']}
df = pd.DataFrame(data)
df
# Out:
#             nama        tempat_kelahiran
# 0    Ahmad Dhani  Surakarta, Jawa Tengah
# 1   Nadin Amizah    Jakarta, DKI Jakarta
# 2  Reza Rahadian   Mojokerto, Jawa Timur

# %% [markdown]
# Memecah nama depan dan nama belakang

# %%
df[['nama_depan', 'nama_belakang']] = df['nama'].str.split(' ', expand=True)
df
# Out:
#             nama        tempat_kelahiran nama_depan nama_belakang
# 0    Ahmad Dhani  Surakarta, Jawa Tengah      Ahmad         Dhani
# 1   Nadin Amizah    Jakarta, DKI Jakarta      Nadin        Amizah
# 2  Reza Rahadian   Mojokerto, Jawa Timur       Reza      Rahadian

# %% [markdown]
# Memecah nama kota dan propinsi

# %%
df[['kota', 'propinsi']] = df['tempat_kelahiran'].str.split(',', expand=True)
df
# Out:
#             nama        tempat_kelahiran nama_depan nama_belakang       kota  \
# 0    Ahmad Dhani  Surakarta, Jawa Tengah      Ahmad         Dhani  Surakarta
# 1   Nadin Amizah    Jakarta, DKI Jakarta      Nadin        Amizah    Jakarta
# 2  Reza Rahadian   Mojokerto, Jawa Timur       Reza      Rahadian  Mojokerto
#
#        propinsi
# 0   Jawa Tengah
# 1   DKI Jakarta
# 2    Jawa Timur

# %% [markdown]
# #16: Menata ulang Data Frame dengan mutiple indexes menggunakan unstack()

# %% [markdown]
# Persiapan Data Frame

# %%
df = pd.read_csv('./data/titanicfull.csv')
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket      fare    cabin embarked
# 0  29.00      0      0   24160  211.3375       B5        S
# 1   0.92      1      2  113781  151.5500  C22 C26        S
# 2   2.00      1      2  113781  151.5500  C22 C26        S
# 3  30.00      1      2  113781  151.5500  C22 C26        S
# 4  25.00      1      2  113781  151.5500  C22 C26        S

# %% [markdown]
# Data Frame dengan multiple indexes dari hasil groupping

# %%
df.groupby(['sex', 'pclass'])['survived'].mean().to_frame()
# Out:
#                survived
# sex    pclass
# female 1       0.965278
#        2       0.886792
#        3       0.490741
# male   1       0.340782
#        2       0.146199
#        3       0.152130

# %% [markdown]
# Menata ulang Data Frame dengan mutiple indexes

# %%
df.groupby(['sex', 'pclass'])['survived'].mean().unstack()
# Out:
# pclass         1         2         3
# sex
# female  0.965278  0.886792  0.490741
# male    0.340782  0.146199  0.152130
